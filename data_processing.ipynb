# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
filenames = []
for file in os.listdir('data'):
    filenames.append(os.path.join('data',file))

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = pd.concat([final_df, df])
        counter+=1
        
final_df
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████▉| 7470/7471 [1:09:17<00:00,  1.80it/s]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[3], line 5
#       3 for file in tqdm(filenames):
#       4     with open(file, 'r') as f:
# ----> 5         df = pd.json_normalize(safe_load(f))
#       6         df['match_id'] = counter
#       7         final_df = pd.concat([final_df, df])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\json\_normalize.py:445, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     443     data = list(data)
#     444 else:
# --> 445     raise NotImplementedError
#     447 # check to see if a simple recursive function is possible to
#     448 # improve performance (see #15621) but only for cases such
#     449 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     450 if (
#     451     record_path is None
#     452     and meta is None
#    (...)
#     455     and max_level is None
#     456 ):
#
# NotImplementedError:

# %%
len(final_df)
# Out:
# 7470

# %%
final_df = final_df.iloc[np.random.permutation(len(final_df))].reset_index(drop=True)

# %%
n = 5000

# %%
final_df.drop(index=final_df.index[:n], inplace=True)

# %%
backup = final_df.copy()

# %%
final_df
# Out:
#                                                 innings  meta.data_version  \
# 5000  [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 5001  [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 5002  [{'1st innings': {'team': 'Sydney Sixers', 'de...                0.9
# 5003  [{'1st innings': {'team': 'Panama', 'deliverie...                0.9
# 5004  [{'1st innings': {'team': 'Mumbai Indians', 'd...                0.9
# ...                                                 ...                ...
# 7465  [{'1st innings': {'team': 'England', 'deliveri...                0.9
# 7466  [{'1st innings': {'team': 'Italy', 'deliveries...                0.9
# 7467  [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 7468  [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 7469  [{'1st innings': {'team': 'Nigeria', 'deliveri...                0.9
#
#      meta.created  meta.revision       info.city  \
# 5000   2012-12-27              4  Port Elizabeth
# 5001   2020-02-17              1    Johannesburg
# 5002   2020-07-24              1          Sydney
# 5003   2020-09-10              1     Morrisville
# 5004   2016-05-21              1          Kanpur
# ...           ...            ...             ...
# 7465   2011-04-25              2         Chennai
# 7466   2019-06-20              1   St Peter Port
# 7467   2014-02-23              2  Port Elizabeth
# 7468   2013-10-21              2       Abu Dhabi
# 7469   2019-09-13              1     Kigali City
#
#                                             info.dates info.gender  \
# 5000                                      [2012-12-26]        male
# 5001                                      [2020-02-09]        male
# 5002                                      [2017-01-13]      female
# 5003                                      [2018-09-26]        male
# 5004                                      [2016-05-21]        male
# ...                                                ...         ...
# 7465                                      [2011-03-17]        male
# 7466                                      [2019-06-16]        male
# 7467  [2014-02-20, 2014-02-21, 2014-02-22, 2014-02-23]        male
# 7468  [2013-10-14, 2013-10-15, 2013-10-16, 2013-10-17]        male
# 7469                                      [2019-09-07]      female
#
#      info.match_type  info.outcome.by.runs info.outcome.winner  ...  \
# 5000             T20                  33.0        South Africa  ...
# 5001             ODI                   NaN             England  ...
# 5002             T20                  16.0       Sydney Sixers  ...
# 5003            IT20                   NaN              Canada  ...
# 5004             T20                   NaN       Gujarat Lions  ...
# ...              ...                   ...                 ...  ...
# 7465             ODI                  18.0             England  ...
# 7466             T20                  11.0               Italy  ...
# 7467            Test                 231.0        South Africa  ...
# 7468            Test                   NaN            Pakistan  ...
# 7469             T20                   NaN              Rwanda  ...
#
#      info.supersubs.Sri Lanka info.supersubs.Bangladesh  \
# 5000                      NaN                       NaN
# 5001                      NaN                       NaN
# 5002                      NaN                       NaN
# 5003                      NaN                       NaN
# 5004                      NaN                       NaN
# ...                       ...                       ...
# 7465                      NaN                       NaN
# 7466                      NaN                       NaN
# 7467                      NaN                       NaN
# 7468                      NaN                       NaN
# 7469                      NaN                       NaN
#
#      info.supersubs.New Zealand info.supersubs.India  \
# 5000                        NaN                  NaN
# 5001                        NaN                  NaN
# 5002                        NaN                  NaN
# 5003                        NaN                  NaN
# 5004                        NaN                  NaN
# ...                         ...                  ...
# 7465                        NaN                  NaN
# 7466                        NaN                  NaN
# 7467                        NaN                  NaN
# 7468                        NaN                  NaN
# 7469                        NaN                  NaN
#
#      info.supersubs.ICC World XI info.supersubs.South Africa  \
# 5000                         NaN                         NaN
# 5001                         NaN                         NaN
# 5002                         NaN                         NaN
# 5003                         NaN                         NaN
# 5004                         NaN                         NaN
# ...                          ...                         ...
# 7465                         NaN                         NaN
# 7466                         NaN                         NaN
# 7467                         NaN                         NaN
# 7468                         NaN                         NaN
# 7469                         NaN                         NaN
#
#       info.supersubs.Pakistan  info.bowl_out  info.outcome.bowl_out  \
# 5000                      NaN            NaN                    NaN
# 5001                      NaN            NaN                    NaN
# 5002                      NaN            NaN                    NaN
# 5003                      NaN            NaN                    NaN
# 5004                      NaN            NaN                    NaN
# ...                       ...            ...                    ...
# 7465                      NaN            NaN                    NaN
# 7466                      NaN            NaN                    NaN
# 7467                      NaN            NaN                    NaN
# 7468                      NaN            NaN                    NaN
# 7469                      NaN            NaN                    NaN
#
#       info.supersubs.West Indies
# 5000                         NaN
# 5001                         NaN
# 5002                         NaN
# 5003                         NaN
# 5004                         NaN
# ...                          ...
# 7465                         NaN
# 7466                         NaN
# 7467                         NaN
# 7468                         NaN
# 7469                         NaN
#
# [2470 rows x 45 columns]

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
final_df
# Out:
#                                                 innings       info.city  \
# 5000  [{'1st innings': {'team': 'South Africa', 'del...  Port Elizabeth
# 5001  [{'1st innings': {'team': 'South Africa', 'del...    Johannesburg
# 5002  [{'1st innings': {'team': 'Sydney Sixers', 'de...          Sydney
# 5003  [{'1st innings': {'team': 'Panama', 'deliverie...     Morrisville
# 5004  [{'1st innings': {'team': 'Mumbai Indians', 'd...          Kanpur
# ...                                                 ...             ...
# 7465  [{'1st innings': {'team': 'England', 'deliveri...         Chennai
# 7466  [{'1st innings': {'team': 'Italy', 'deliveries...   St Peter Port
# 7467  [{'1st innings': {'team': 'South Africa', 'del...  Port Elizabeth
# 7468  [{'1st innings': {'team': 'South Africa', 'del...       Abu Dhabi
# 7469  [{'1st innings': {'team': 'Nigeria', 'deliveri...     Kigali City
#
#                                             info.dates info.gender  \
# 5000                                      [2012-12-26]        male
# 5001                                      [2020-02-09]        male
# 5002                                      [2017-01-13]      female
# 5003                                      [2018-09-26]        male
# 5004                                      [2016-05-21]        male
# ...                                                ...         ...
# 7465                                      [2011-03-17]        male
# 7466                                      [2019-06-16]        male
# 7467  [2014-02-20, 2014-02-21, 2014-02-22, 2014-02-23]        male
# 7468  [2013-10-14, 2013-10-15, 2013-10-16, 2013-10-17]        male
# 7469                                      [2019-09-07]      female
#
#      info.match_type info.outcome.winner info.player_of_match  \
# 5000             T20        South Africa           [H Davids]
# 5001             ODI             England          [AU Rashid]
# 5002             T20       Sydney Sixers           [EA Perry]
# 5003            IT20              Canada           [C Pervez]
# 5004             T20       Gujarat Lions           [SK Raina]
# ...              ...                 ...                  ...
# 7465             ODI             England        [JC Tredwell]
# 7466             T20               Italy                  NaN
# 7467            Test        South Africa          [JP Duminy]
# 7468            Test            Pakistan    [Khurram Manzoor]
# 7469             T20              Rwanda           [S Sunday]
#
#                               info.teams info.toss.decision  \
# 5000         [South Africa, New Zealand]                bat
# 5001             [South Africa, England]              field
# 5002  [Sydney Sixers, Hobart Hurricanes]              field
# 5003                    [Panama, Canada]                bat
# 5004     [Gujarat Lions, Mumbai Indians]              field
# ...                                  ...                ...
# 7465              [England, West Indies]                bat
# 7466                   [Guernsey, Italy]              field
# 7467           [South Africa, Australia]                bat
# 7468            [Pakistan, South Africa]                bat
# 7469                   [Rwanda, Nigeria]                bat
#
#        info.toss.winner  ... info.supersubs.England info.supersubs.Africa XI  \
# 5000       South Africa  ...                    NaN                      NaN
# 5001            England  ...                    NaN                      NaN
# 5002  Hobart Hurricanes  ...                    NaN                      NaN
# 5003             Panama  ...                    NaN                      NaN
# 5004      Gujarat Lions  ...                    NaN                      NaN
# ...                 ...  ...                    ...                      ...
# 7465            England  ...                    NaN                      NaN
# 7466           Guernsey  ...                    NaN                      NaN
# 7467       South Africa  ...                    NaN                      NaN
# 7468       South Africa  ...                    NaN                      NaN
# 7469            Nigeria  ...                    NaN                      NaN
#
#       info.supersubs.Asia XI  info.supersubs.Zimbabwe  \
# 5000                     NaN                      NaN
# 5001                     NaN                      NaN
# 5002                     NaN                      NaN
# 5003                     NaN                      NaN
# 5004                     NaN                      NaN
# ...                      ...                      ...
# 7465                     NaN                      NaN
# 7466                     NaN                      NaN
# 7467                     NaN                      NaN
# 7468                     NaN                      NaN
# 7469                     NaN                      NaN
#
#       info.supersubs.Sri Lanka info.supersubs.Bangladesh info.supersubs.India  \
# 5000                       NaN                       NaN                  NaN
# 5001                       NaN                       NaN                  NaN
# 5002                       NaN                       NaN                  NaN
# 5003                       NaN                       NaN                  NaN
# 5004                       NaN                       NaN                  NaN
# ...                        ...                       ...                  ...
# 7465                       NaN                       NaN                  NaN
# 7466                       NaN                       NaN                  NaN
# 7467                       NaN                       NaN                  NaN
# 7468                       NaN                       NaN                  NaN
# 7469                       NaN                       NaN                  NaN
#
#      info.supersubs.ICC World XI info.supersubs.Pakistan  \
# 5000                         NaN                     NaN
# 5001                         NaN                     NaN
# 5002                         NaN                     NaN
# 5003                         NaN                     NaN
# 5004                         NaN                     NaN
# ...                          ...                     ...
# 7465                         NaN                     NaN
# 7466                         NaN                     NaN
# 7467                         NaN                     NaN
# 7468                         NaN                     NaN
# 7469                         NaN                     NaN
#
#      info.supersubs.West Indies
# 5000                        NaN
# 5001                        NaN
# 5002                        NaN
# 5003                        NaN
# 5004                        NaN
# ...                         ...
# 7465                        NaN
# 7466                        NaN
# 7467                        NaN
# 7468                        NaN
# 7469                        NaN
#
# [2470 rows x 31 columns]

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace=True)
# Out:
# C:\Users\kamag\AppData\Local\Temp\ipykernel_6340\3352087688.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.gender'],inplace=True)

# %%
final_df
# Out:
#                                                 innings       info.city  \
# 5000  [{'1st innings': {'team': 'South Africa', 'del...  Port Elizabeth
# 5001  [{'1st innings': {'team': 'South Africa', 'del...    Johannesburg
# 5003  [{'1st innings': {'team': 'Panama', 'deliverie...     Morrisville
# 5004  [{'1st innings': {'team': 'Mumbai Indians', 'd...          Kanpur
# 5005  [{'1st innings': {'team': 'Sri Lanka', 'delive...             NaN
# ...                                                 ...             ...
# 7464  [{'1st innings': {'team': 'South Africa', 'del...      Birmingham
# 7465  [{'1st innings': {'team': 'England', 'deliveri...         Chennai
# 7466  [{'1st innings': {'team': 'Italy', 'deliveries...   St Peter Port
# 7467  [{'1st innings': {'team': 'South Africa', 'del...  Port Elizabeth
# 7468  [{'1st innings': {'team': 'South Africa', 'del...       Abu Dhabi
#
#                                             info.dates info.match_type  \
# 5000                                      [2012-12-26]             T20
# 5001                                      [2020-02-09]             ODI
# 5003                                      [2018-09-26]            IT20
# 5004                                      [2016-05-21]             T20
# 5005                                      [2014-12-13]             ODI
# ...                                                ...             ...
# 7464                                      [2017-06-07]             ODI
# 7465                                      [2011-03-17]             ODI
# 7466                                      [2019-06-16]             T20
# 7467  [2014-02-20, 2014-02-21, 2014-02-22, 2014-02-23]            Test
# 7468  [2013-10-14, 2013-10-15, 2013-10-16, 2013-10-17]            Test
#
#      info.outcome.winner info.player_of_match  \
# 5000        South Africa           [H Davids]
# 5001             England          [AU Rashid]
# 5003              Canada           [C Pervez]
# 5004       Gujarat Lions           [SK Raina]
# 5005           Sri Lanka      [KC Sangakkara]
# ...                  ...                  ...
# 7464            Pakistan          [Hasan Ali]
# 7465             England        [JC Tredwell]
# 7466               Italy                  NaN
# 7467        South Africa          [JP Duminy]
# 7468            Pakistan    [Khurram Manzoor]
#
#                            info.teams info.toss.decision info.toss.winner  \
# 5000      [South Africa, New Zealand]                bat     South Africa
# 5001          [South Africa, England]              field          England
# 5003                 [Panama, Canada]                bat           Panama
# 5004  [Gujarat Lions, Mumbai Indians]              field    Gujarat Lions
# 5005             [Sri Lanka, England]                bat        Sri Lanka
# ...                               ...                ...              ...
# 7464         [Pakistan, South Africa]                bat     South Africa
# 7465           [England, West Indies]                bat          England
# 7466                [Guernsey, Italy]              field         Guernsey
# 7467        [South Africa, Australia]                bat     South Africa
# 7468         [Pakistan, South Africa]                bat     South Africa
#
#                            info.umpires  ... info.supersubs.England  \
# 5000          [JD Cloete, AT Holdstock]  ...                    NaN
# 5001          [S George, GO Brathwaite]  ...                    NaN
# 5003            [SN Bandekar, H Grewal]  ...                    NaN
# 5004          [AK Chaudhary, CK Nandan]  ...                    NaN
# 5005      [REJ Martinesz, BNJ Oxenford]  ...                    NaN
# ...                                 ...  ...                    ...
# 7464           [RK Illingworth, S Ravi]  ...                    NaN
# 7465           [SJ Davis, BNJ Oxenford]  ...                    NaN
# 7466             [AG Wharf, MV Waldron]  ...                    NaN
# 7467  [HDPK Dharmasena, RK Illingworth]  ...                    NaN
# 7468            [PR Reiffel, RJ Tucker]  ...                    NaN
#
#       info.supersubs.Africa XI  info.supersubs.Asia XI  \
# 5000                       NaN                     NaN
# 5001                       NaN                     NaN
# 5003                       NaN                     NaN
# 5004                       NaN                     NaN
# 5005                       NaN                     NaN
# ...                        ...                     ...
# 7464                       NaN                     NaN
# 7465                       NaN                     NaN
# 7466                       NaN                     NaN
# 7467                       NaN                     NaN
# 7468                       NaN                     NaN
#
#       info.supersubs.Zimbabwe info.supersubs.Sri Lanka  \
# 5000                      NaN                      NaN
# 5001                      NaN                      NaN
# 5003                      NaN                      NaN
# 5004                      NaN                      NaN
# 5005                      NaN                      NaN
# ...                       ...                      ...
# 7464                      NaN                      NaN
# 7465                      NaN                      NaN
# 7466                      NaN                      NaN
# 7467                      NaN                      NaN
# 7468                      NaN                      NaN
#
#      info.supersubs.Bangladesh info.supersubs.India  \
# 5000                       NaN                  NaN
# 5001                       NaN                  NaN
# 5003                       NaN                  NaN
# 5004                       NaN                  NaN
# 5005                       NaN                  NaN
# ...                        ...                  ...
# 7464                       NaN                  NaN
# 7465                       NaN                  NaN
# 7466                       NaN                  NaN
# 7467                       NaN                  NaN
# 7468                       NaN                  NaN
#
#      info.supersubs.ICC World XI info.supersubs.Pakistan  \
# 5000                         NaN                     NaN
# 5001                         NaN                     NaN
# 5003                         NaN                     NaN
# 5004                         NaN                     NaN
# 5005                         NaN                     NaN
# ...                          ...                     ...
# 7464                         NaN                     NaN
# 7465                         NaN                     NaN
# 7466                         NaN                     NaN
# 7467                         NaN                     NaN
# 7468                         NaN                     NaN
#
#      info.supersubs.West Indies
# 5000                        NaN
# 5001                        NaN
# 5003                        NaN
# 5004                        NaN
# 5005                        NaN
# ...                         ...
# 7464                        NaN
# 7465                        NaN
# 7466                        NaN
# 7467                        NaN
# 7468                        NaN
#
# [2095 rows x 30 columns]

# %%
final_df['info.match_type'].value_counts()
# Out:
# info.match_type
# T20     1127
# ODI      583
# Test     193
# ODM      105
# IT20      78
# MDM        9
# Name: count, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# info.overs
# 20.0    1204
# 50.0     689
# Name: count, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
# Out:
# C:\Users\kamag\AppData\Local\Temp\ipykernel_6340\1862075967.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.overs','info.match_type'],inplace=True)

# %%
final_df
# Out:
#                                                 innings       info.city  \
# 5000  [{'1st innings': {'team': 'South Africa', 'del...  Port Elizabeth
# 5003  [{'1st innings': {'team': 'Panama', 'deliverie...     Morrisville
# 5004  [{'1st innings': {'team': 'Mumbai Indians', 'd...          Kanpur
# 5009  [{'1st innings': {'team': 'Mumbai Indians', 'd...          Mumbai
# 5010  [{'1st innings': {'team': 'Romania', 'deliveri...             NaN
# ...                                                 ...             ...
# 7459  [{'1st innings': {'team': 'Northamptonshire', ...    Chesterfield
# 7461  [{'1st innings': {'team': 'Delhi Daredevils', ...           Delhi
# 7462  [{'1st innings': {'team': 'Sunrisers Hyderabad...       Hyderabad
# 7463  [{'1st innings': {'team': 'Zimbabwe', 'deliver...             NaN
# 7466  [{'1st innings': {'team': 'Italy', 'deliveries...   St Peter Port
#
#         info.dates  info.outcome.winner info.player_of_match  \
# 5000  [2012-12-26]         South Africa           [H Davids]
# 5003  [2018-09-26]               Canada           [C Pervez]
# 5004  [2016-05-21]        Gujarat Lions           [SK Raina]
# 5009  [2010-04-13]       Mumbai Indians         [KA Pollard]
# 5010  [2020-10-17]              Romania        [R Satheesan]
# ...            ...                  ...                  ...
# 7459  [2015-07-05]     Northamptonshire         [WJ Durston]
# 7461  [2016-04-23]     Delhi Daredevils          [SV Samson]
# 7462  [2019-03-31]  Sunrisers Hyderabad        [JM Bairstow]
# 7463  [2018-02-05]          Afghanistan      [Mohammad Nabi]
# 7466  [2019-06-16]                Italy                  NaN
#
#                                              info.teams info.toss.decision  \
# 5000                        [South Africa, New Zealand]                bat
# 5003                                   [Panama, Canada]                bat
# 5004                    [Gujarat Lions, Mumbai Indians]              field
# 5009                 [Mumbai Indians, Delhi Daredevils]                bat
# 5010                                [Romania, Bulgaria]                bat
# ...                                                 ...                ...
# 7459                     [Northamptonshire, Derbyshire]              field
# 7461                 [Delhi Daredevils, Mumbai Indians]              field
# 7462  [Sunrisers Hyderabad, Royal Challengers Bangal...              field
# 7463                            [Zimbabwe, Afghanistan]              field
# 7466                                  [Guernsey, Italy]              field
#
#                  info.toss.winner                              info.umpires  \
# 5000                 South Africa                 [JD Cloete, AT Holdstock]
# 5003                       Panama                   [SN Bandekar, H Grewal]
# 5004                Gujarat Lions                 [AK Chaudhary, CK Nandan]
# 5009               Mumbai Indians                     [S Asnani, DJ Harper]
# 5010                      Romania      [Dharmendra Manani, Taranjeet Singh]
# ...                           ...                                       ...
# 7459                   Derbyshire                  [MJ Saggers, PK Baldwin]
# 7461               Mumbai Indians                   [S Ravi, C Shamshuddin]
# 7462  Royal Challengers Bangalore           [KN Ananthapadmanabhan, S Ravi]
# 7463                  Afghanistan  [Bismillah Shinwari, Ahmed Shah Durrani]
# 7466                     Guernsey                    [AG Wharf, MV Waldron]
#
#                               info.venue  ...  info.supersubs.England  \
# 5000                    St George's Park  ...                     NaN
# 5003                  Church Street Park  ...                     NaN
# 5004                          Green Park  ...                     NaN
# 5009                   Brabourne Stadium  ...                     NaN
# 5010        Moara Vlasiei Cricket Ground  ...                     NaN
# ...                                  ...  ...                     ...
# 7459                        Queen's Park  ...                     NaN
# 7461                    Feroz Shah Kotla  ...                     NaN
# 7462  Rajiv Gandhi International Stadium  ...                     NaN
# 7463             Sharjah Cricket Stadium  ...                     NaN
# 7466                       College Field  ...                     NaN
#
#       info.supersubs.Africa XI info.supersubs.Asia XI info.supersubs.Zimbabwe  \
# 5000                       NaN                    NaN                     NaN
# 5003                       NaN                    NaN                     NaN
# 5004                       NaN                    NaN                     NaN
# 5009                       NaN                    NaN                     NaN
# 5010                       NaN                    NaN                     NaN
# ...                        ...                    ...                     ...
# 7459                       NaN                    NaN                     NaN
# 7461                       NaN                    NaN                     NaN
# 7462                       NaN                    NaN                     NaN
# 7463                       NaN                    NaN                     NaN
# 7466                       NaN                    NaN                     NaN
#
#      info.supersubs.Sri Lanka info.supersubs.Bangladesh info.supersubs.India  \
# 5000                      NaN                       NaN                  NaN
# 5003                      NaN                       NaN                  NaN
# 5004                      NaN                       NaN                  NaN
# 5009                      NaN                       NaN                  NaN
# 5010                      NaN                       NaN                  NaN
# ...                       ...                       ...                  ...
# 7459                      NaN                       NaN                  NaN
# 7461                      NaN                       NaN                  NaN
# 7462                      NaN                       NaN                  NaN
# 7463                      NaN                       NaN                  NaN
# 7466                      NaN                       NaN                  NaN
#
#      info.supersubs.ICC World XI info.supersubs.Pakistan  \
# 5000                         NaN                     NaN
# 5003                         NaN                     NaN
# 5004                         NaN                     NaN
# 5009                         NaN                     NaN
# 5010                         NaN                     NaN
# ...                          ...                     ...
# 7459                         NaN                     NaN
# 7461                         NaN                     NaN
# 7462                         NaN                     NaN
# 7463                         NaN                     NaN
# 7466                         NaN                     NaN
#
#      info.supersubs.West Indies
# 5000                        NaN
# 5003                        NaN
# 5004                        NaN
# 5009                        NaN
# 5010                        NaN
# ...                         ...
# 7459                        NaN
# 7461                        NaN
# 7462                        NaN
# 7463                        NaN
# 7466                        NaN
#
# [1204 rows x 28 columns]

# %%
import pickle
pickle.dump(final_df,open('check_point1.pkl','wb'))

# %%
matches = pickle.load(open('check_point1.pkl','rb'))
matches
# Out:
#                                                 innings       info.city  \
# 5000  [{'1st innings': {'team': 'South Africa', 'del...  Port Elizabeth
# 5003  [{'1st innings': {'team': 'Panama', 'deliverie...     Morrisville
# 5004  [{'1st innings': {'team': 'Mumbai Indians', 'd...          Kanpur
# 5009  [{'1st innings': {'team': 'Mumbai Indians', 'd...          Mumbai
# 5010  [{'1st innings': {'team': 'Romania', 'deliveri...             NaN
# ...                                                 ...             ...
# 7459  [{'1st innings': {'team': 'Northamptonshire', ...    Chesterfield
# 7461  [{'1st innings': {'team': 'Delhi Daredevils', ...           Delhi
# 7462  [{'1st innings': {'team': 'Sunrisers Hyderabad...       Hyderabad
# 7463  [{'1st innings': {'team': 'Zimbabwe', 'deliver...             NaN
# 7466  [{'1st innings': {'team': 'Italy', 'deliveries...   St Peter Port
#
#         info.dates  info.outcome.winner info.player_of_match  \
# 5000  [2012-12-26]         South Africa           [H Davids]
# 5003  [2018-09-26]               Canada           [C Pervez]
# 5004  [2016-05-21]        Gujarat Lions           [SK Raina]
# 5009  [2010-04-13]       Mumbai Indians         [KA Pollard]
# 5010  [2020-10-17]              Romania        [R Satheesan]
# ...            ...                  ...                  ...
# 7459  [2015-07-05]     Northamptonshire         [WJ Durston]
# 7461  [2016-04-23]     Delhi Daredevils          [SV Samson]
# 7462  [2019-03-31]  Sunrisers Hyderabad        [JM Bairstow]
# 7463  [2018-02-05]          Afghanistan      [Mohammad Nabi]
# 7466  [2019-06-16]                Italy                  NaN
#
#                                              info.teams info.toss.decision  \
# 5000                        [South Africa, New Zealand]                bat
# 5003                                   [Panama, Canada]                bat
# 5004                    [Gujarat Lions, Mumbai Indians]              field
# 5009                 [Mumbai Indians, Delhi Daredevils]                bat
# 5010                                [Romania, Bulgaria]                bat
# ...                                                 ...                ...
# 7459                     [Northamptonshire, Derbyshire]              field
# 7461                 [Delhi Daredevils, Mumbai Indians]              field
# 7462  [Sunrisers Hyderabad, Royal Challengers Bangal...              field
# 7463                            [Zimbabwe, Afghanistan]              field
# 7466                                  [Guernsey, Italy]              field
#
#                  info.toss.winner                              info.umpires  \
# 5000                 South Africa                 [JD Cloete, AT Holdstock]
# 5003                       Panama                   [SN Bandekar, H Grewal]
# 5004                Gujarat Lions                 [AK Chaudhary, CK Nandan]
# 5009               Mumbai Indians                     [S Asnani, DJ Harper]
# 5010                      Romania      [Dharmendra Manani, Taranjeet Singh]
# ...                           ...                                       ...
# 7459                   Derbyshire                  [MJ Saggers, PK Baldwin]
# 7461               Mumbai Indians                   [S Ravi, C Shamshuddin]
# 7462  Royal Challengers Bangalore           [KN Ananthapadmanabhan, S Ravi]
# 7463                  Afghanistan  [Bismillah Shinwari, Ahmed Shah Durrani]
# 7466                     Guernsey                    [AG Wharf, MV Waldron]
#
#                               info.venue  ...  info.supersubs.England  \
# 5000                    St George's Park  ...                     NaN
# 5003                  Church Street Park  ...                     NaN
# 5004                          Green Park  ...                     NaN
# 5009                   Brabourne Stadium  ...                     NaN
# 5010        Moara Vlasiei Cricket Ground  ...                     NaN
# ...                                  ...  ...                     ...
# 7459                        Queen's Park  ...                     NaN
# 7461                    Feroz Shah Kotla  ...                     NaN
# 7462  Rajiv Gandhi International Stadium  ...                     NaN
# 7463             Sharjah Cricket Stadium  ...                     NaN
# 7466                       College Field  ...                     NaN
#
#       info.supersubs.Africa XI info.supersubs.Asia XI info.supersubs.Zimbabwe  \
# 5000                       NaN                    NaN                     NaN
# 5003                       NaN                    NaN                     NaN
# 5004                       NaN                    NaN                     NaN
# 5009                       NaN                    NaN                     NaN
# 5010                       NaN                    NaN                     NaN
# ...                        ...                    ...                     ...
# 7459                       NaN                    NaN                     NaN
# 7461                       NaN                    NaN                     NaN
# 7462                       NaN                    NaN                     NaN
# 7463                       NaN                    NaN                     NaN
# 7466                       NaN                    NaN                     NaN
#
#      info.supersubs.Sri Lanka info.supersubs.Bangladesh info.supersubs.India  \
# 5000                      NaN                       NaN                  NaN
# 5003                      NaN                       NaN                  NaN
# 5004                      NaN                       NaN                  NaN
# 5009                      NaN                       NaN                  NaN
# 5010                      NaN                       NaN                  NaN
# ...                       ...                       ...                  ...
# 7459                      NaN                       NaN                  NaN
# 7461                      NaN                       NaN                  NaN
# 7462                      NaN                       NaN                  NaN
# 7463                      NaN                       NaN                  NaN
# 7466                      NaN                       NaN                  NaN
#
#      info.supersubs.ICC World XI info.supersubs.Pakistan  \
# 5000                         NaN                     NaN
# 5003                         NaN                     NaN
# 5004                         NaN                     NaN
# 5009                         NaN                     NaN
# 5010                         NaN                     NaN
# ...                          ...                     ...
# 7459                         NaN                     NaN
# 7461                         NaN                     NaN
# 7462                         NaN                     NaN
# 7463                         NaN                     NaN
# 7466                         NaN                     NaN
#
#      info.supersubs.West Indies
# 5000                        NaN
# 5003                        NaN
# 5004                        NaN
# 5009                        NaN
# 5010                        NaN
# ...                         ...
# 7459                        NaN
# 7461                        NaN
# 7462                        NaN
# 7463                        NaN
# 7466                        NaN
#
# [1204 rows x 28 columns]

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = pd.concat([delivery_df , loop_df])

# %%
delivery_df
# Out:
#      match_id                        teams  batting_team  ball  \
# 0           2  [South Africa, New Zealand]  South Africa   0.1
# 1           2  [South Africa, New Zealand]  South Africa   0.2
# 2           2  [South Africa, New Zealand]  South Africa   0.3
# 3           2  [South Africa, New Zealand]  South Africa   0.4
# 4           2  [South Africa, New Zealand]  South Africa   0.5
# ..        ...                          ...           ...   ...
# 114      1205            [Guernsey, Italy]         Italy  18.4
# 115      1205            [Guernsey, Italy]         Italy  18.5
# 116      1205            [Guernsey, Italy]         Italy  18.6
# 117      1205            [Guernsey, Italy]         Italy  19.1
# 118      1205            [Guernsey, Italy]         Italy  19.2
#
#               batsman          bowler  runs player_dismissed            city  \
# 0            H Davids  MJ McClenaghan     1                0  Port Elizabeth
# 1        F du Plessis  MJ McClenaghan     0                0  Port Elizabeth
# 2        F du Plessis  MJ McClenaghan     0                0  Port Elizabeth
# 3        F du Plessis  MJ McClenaghan     0                0  Port Elizabeth
# 4        F du Plessis  MJ McClenaghan     1                0  Port Elizabeth
# ..                ...             ...   ...              ...             ...
# 114      Baljit Singh     W Peatfield     0     Baljit Singh   St Peter Port
# 115  Charanjeet Singh     W Peatfield     4                0   St Peter Port
# 116  Charanjeet Singh     W Peatfield     0                0   St Peter Port
# 117      S Arachchige       DR Hooper     0                0   St Peter Port
# 118      S Arachchige       DR Hooper     0     S Arachchige   St Peter Port
#
#                 venue
# 0    St George's Park
# 1    St George's Park
# 2    St George's Park
# 3    St George's Park
# 4    St George's Park
# ..                ...
# 114     College Field
# 115     College Field
# 116     College Field
# 117     College Field
# 118     College Field
#
# [144570 rows x 10 columns]

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#      match_id                        teams  batting_team  ball  \
# 0           2  [South Africa, New Zealand]  South Africa   0.1
# 1           2  [South Africa, New Zealand]  South Africa   0.2
# 2           2  [South Africa, New Zealand]  South Africa   0.3
# 3           2  [South Africa, New Zealand]  South Africa   0.4
# 4           2  [South Africa, New Zealand]  South Africa   0.5
# ..        ...                          ...           ...   ...
# 114      1205            [Guernsey, Italy]         Italy  18.4
# 115      1205            [Guernsey, Italy]         Italy  18.5
# 116      1205            [Guernsey, Italy]         Italy  18.6
# 117      1205            [Guernsey, Italy]         Italy  19.1
# 118      1205            [Guernsey, Italy]         Italy  19.2
#
#               batsman          bowler  runs player_dismissed            city  \
# 0            H Davids  MJ McClenaghan     1                0  Port Elizabeth
# 1        F du Plessis  MJ McClenaghan     0                0  Port Elizabeth
# 2        F du Plessis  MJ McClenaghan     0                0  Port Elizabeth
# 3        F du Plessis  MJ McClenaghan     0                0  Port Elizabeth
# 4        F du Plessis  MJ McClenaghan     1                0  Port Elizabeth
# ..                ...             ...   ...              ...             ...
# 114      Baljit Singh     W Peatfield     0     Baljit Singh   St Peter Port
# 115  Charanjeet Singh     W Peatfield     4                0   St Peter Port
# 116  Charanjeet Singh     W Peatfield     0                0   St Peter Port
# 117      S Arachchige       DR Hooper     0                0   St Peter Port
# 118      S Arachchige       DR Hooper     0     S Arachchige   St Peter Port
#
#                 venue bowling_team
# 0    St George's Park  New Zealand
# 1    St George's Park  New Zealand
# 2    St George's Park  New Zealand
# 3    St George's Park  New Zealand
# 4    St George's Park  New Zealand
# ..                ...          ...
# 114     College Field     Guernsey
# 115     College Field     Guernsey
# 116     College Field     Guernsey
# 117     College Field     Guernsey
# 118     College Field     Guernsey
#
# [144570 rows x 11 columns]

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['South Africa', 'Panama', 'Mumbai Indians', 'Romania',
#        'Royal Challengers Bangalore', 'Chennai Super Kings',
#        'Leicestershire', 'Pakistan', 'Lahore Qalandars', 'Worcestershire',
#        'Malaysia', 'Kolkata Knight Riders', 'Canada', 'Papua New Guinea',
#        'Pune Warriors', 'Jersey', 'Islamabad United', 'Barbados Tridents',
#        'Samoa', 'Kings XI Punjab', 'Rajasthan Royals', 'England',
#        'Namibia', 'Glamorgan', 'Ireland', 'Kent', 'Zimbabwe', 'Myanmar',
#        'Australia', 'Multan Sultans', 'St Kitts and Nevis Patriots',
#        'Yorkshire', 'India', 'Durham', 'West Indies', 'Delhi Daredevils',
#        'Deccan Chargers', 'Delhi Capitals', 'Lancashire',
#        'Sunrisers Hyderabad', 'Kochi Tuskers Kerala', 'Germany',
#        'Hong Kong', 'Peshawar Zalmi', 'New Zealand', 'St Lucia Stars',
#        'Melbourne Stars', 'Brisbane Heat', 'Derbyshire', 'Somerset',
#        'Middlesex', 'Surrey', 'Hampshire', 'Perth Scorchers',
#        'Melbourne Renegades', 'Gibraltar', 'Fiji', 'Nottinghamshire',
#        'Adelaide Strikers', 'Sydney Sixers', 'Nepal', 'Sri Lanka',
#        'Essex', 'United Arab Emirates', 'Afghanistan',
#        'Hobart Hurricanes', 'Trinbago Knight Riders', 'Sussex',
#        'Sydney Thunder', 'Netherlands', 'Israel', 'Oman',
#        'Quetta Gladiators', 'Maldives', 'Bangladesh', 'Karachi Kings',
#        'Kenya', 'Kuwait', 'Nigeria', 'Rising Pune Supergiants',
#        'St Lucia Zouks', 'Scotland', 'Italy', 'Guyana Amazon Warriors',
#        'Japan', 'Gloucestershire', 'Gujarat Lions', 'Jamaica Tallawahs',
#        'Rising Pune Supergiant', 'Northamptonshire', 'Guernsey',
#        'Singapore', 'St Helena', 'Bermuda', 'Swaziland', 'Warwickshire',
#        'Philippines', 'Mozambique', 'Cayman Islands', 'Denmark',
#        'Trinidad & Tobago Red Steel', 'Rwanda', 'Sweden', 'Thailand',
#        'Uganda', 'Gambia', 'Antigua Hawksbills', 'Bulgaria',
#        'Birmingham Bears', 'Belgium', 'China', 'Norway',
#        'United States of America', 'Ghana', 'Iran', 'Vanuatu',
#        'Isle of Man', 'Spain', 'Belize', 'Saudi Arabia', 'Botswana'],
#       dtype=object)

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id  batting_team  ball        batsman          bowler  runs  \
# 0           2  South Africa   0.1       H Davids  MJ McClenaghan     1
# 1           2  South Africa   0.2   F du Plessis  MJ McClenaghan     0
# 2           2  South Africa   0.3   F du Plessis  MJ McClenaghan     0
# 3           2  South Africa   0.4   F du Plessis  MJ McClenaghan     0
# 4           2  South Africa   0.5   F du Plessis  MJ McClenaghan     1
# ..        ...           ...   ...            ...             ...   ...
# 105      1199      Pakistan  16.6  Mohammad Sami        R Ashwin     0
# 106      1199      Pakistan  16.7  Mohammad Sami        R Ashwin     1
# 107      1199      Pakistan  17.1  Mohammad Sami       HH Pandya     0
# 108      1199      Pakistan  17.2  Mohammad Sami       HH Pandya     0
# 109      1199      Pakistan  17.3  Mohammad Amir       HH Pandya     0
#
#     player_dismissed            city                          venue  \
# 0                  0  Port Elizabeth               St George's Park
# 1                  0  Port Elizabeth               St George's Park
# 2                  0  Port Elizabeth               St George's Park
# 3                  0  Port Elizabeth               St George's Park
# 4                  0  Port Elizabeth               St George's Park
# ..               ...             ...                            ...
# 105                0          Mirpur  Shere Bangla National Stadium
# 106                0          Mirpur  Shere Bangla National Stadium
# 107                0          Mirpur  Shere Bangla National Stadium
# 108    Mohammad Sami          Mirpur  Shere Bangla National Stadium
# 109    Mohammad Amir          Mirpur  Shere Bangla National Stadium
#
#     bowling_team
# 0    New Zealand
# 1    New Zealand
# 2    New Zealand
# 3    New Zealand
# 4    New Zealand
# ..           ...
# 105        India
# 106        India
# 107        India
# 108        India
# 109        India
#
# [20705 rows x 10 columns]

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#      match_id  batting_team bowling_team  ball  runs player_dismissed  \
# 0           2  South Africa  New Zealand   0.1     1                0
# 1           2  South Africa  New Zealand   0.2     0                0
# 2           2  South Africa  New Zealand   0.3     0                0
# 3           2  South Africa  New Zealand   0.4     0                0
# 4           2  South Africa  New Zealand   0.5     1                0
# ..        ...           ...          ...   ...   ...              ...
# 105      1199      Pakistan        India  16.6     0                0
# 106      1199      Pakistan        India  16.7     1                0
# 107      1199      Pakistan        India  17.1     0                0
# 108      1199      Pakistan        India  17.2     0    Mohammad Sami
# 109      1199      Pakistan        India  17.3     0    Mohammad Amir
#
#                city                          venue
# 0    Port Elizabeth               St George's Park
# 1    Port Elizabeth               St George's Park
# 2    Port Elizabeth               St George's Park
# 3    Port Elizabeth               St George's Park
# 4    Port Elizabeth               St George's Park
# ..              ...                            ...
# 105          Mirpur  Shere Bangla National Stadium
# 106          Mirpur  Shere Bangla National Stadium
# 107          Mirpur  Shere Bangla National Stadium
# 108          Mirpur  Shere Bangla National Stadium
# 109          Mirpur  Shere Bangla National Stadium
#
# [20705 rows x 8 columns]

# %%
pickle.dump(output,open('check_point2.pkl','wb'))

# %%
output[output['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Pallekele International Cricket Stadium    745
# Dubai International Cricket Stadium        739
# Melbourne Cricket Ground                   233
# Sharjah Cricket Stadium                    127
# Sydney Cricket Ground                      126
# Adelaide Oval                              124
# Name: count, dtype: int64

# %%
x = np.where(output['city'].isnull(), output['venue'].str.split().apply(lambda x:x[0]), output['city'])

# %%
output['city'] = x
# Out:
# C:\Users\kamag\AppData\Local\Temp\ipykernel_6340\2208188131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['city'] = x

# %%
output.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
output.drop(columns=['venue'],inplace=True)
# Out:
# C:\Users\kamag\AppData\Local\Temp\ipykernel_6340\2962604362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output.drop(columns=['venue'],inplace=True)

# %%
output
# Out:
#      match_id  batting_team bowling_team  ball  runs player_dismissed  \
# 0           2  South Africa  New Zealand   0.1     1                0
# 1           2  South Africa  New Zealand   0.2     0                0
# 2           2  South Africa  New Zealand   0.3     0                0
# 3           2  South Africa  New Zealand   0.4     0                0
# 4           2  South Africa  New Zealand   0.5     1                0
# ..        ...           ...          ...   ...   ...              ...
# 105      1199      Pakistan        India  16.6     0                0
# 106      1199      Pakistan        India  16.7     1                0
# 107      1199      Pakistan        India  17.1     0                0
# 108      1199      Pakistan        India  17.2     0    Mohammad Sami
# 109      1199      Pakistan        India  17.3     0    Mohammad Amir
#
#                city
# 0    Port Elizabeth
# 1    Port Elizabeth
# 2    Port Elizabeth
# 3    Port Elizabeth
# 4    Port Elizabeth
# ..              ...
# 105          Mirpur
# 106          Mirpur
# 107          Mirpur
# 108          Mirpur
# 109          Mirpur
#
# [20705 rows x 7 columns]

# %%
total_df = output.groupby('match_id').sum()['runs'].reset_index()
output = output.merge(total_df,on='match_id')

# %%
output
# Out:
#        match_id  batting_team bowling_team  ball  runs_x player_dismissed  \
# 0             2  South Africa  New Zealand   0.1       1                0
# 1             2  South Africa  New Zealand   0.2       0                0
# 2             2  South Africa  New Zealand   0.3       0                0
# 3             2  South Africa  New Zealand   0.4       0                0
# 4             2  South Africa  New Zealand   0.5       1                0
# ...         ...           ...          ...   ...     ...              ...
# 20700      1199      Pakistan        India  16.6       0                0
# 20701      1199      Pakistan        India  16.7       1                0
# 20702      1199      Pakistan        India  17.1       0                0
# 20703      1199      Pakistan        India  17.2       0    Mohammad Sami
# 20704      1199      Pakistan        India  17.3       0    Mohammad Amir
#
#                  city  runs_y
# 0      Port Elizabeth     179
# 1      Port Elizabeth     179
# 2      Port Elizabeth     179
# 3      Port Elizabeth     179
# 4      Port Elizabeth     179
# ...               ...     ...
# 20700          Mirpur      83
# 20701          Mirpur      83
# 20702          Mirpur      83
# 20703          Mirpur      83
# 20704          Mirpur      83
#
# [20705 rows x 8 columns]

# %%
# output1 = output.groupby('match_id')
output['current_score'] = output.groupby('match_id')['runs_x'].cumsum()
# ['runs_x']

# %%
output['over'] = output['ball'].apply(lambda x:str(x).split(".")[0])
output['ball_no'] = output['ball'].apply(lambda x:str(x).split(".")[1])

# %%
output['balls_bowled'] = (output['over'].astype('int')*6) + output['ball_no'].astype('int')

# %%
output['crr'] = round((output['current_score']*6)/output['balls_bowled'],2)

# %%
output['player_dismissed'] = output['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
output['player_dismissed'] = output['player_dismissed'].astype('int')
output['player_dismissed'] = output.groupby('match_id')['player_dismissed'].cumsum()
output['wickets_left'] = 10 - output['player_dismissed']

# %%
final_df = output[['match_id','batting_team','bowling_team','runs_x','current_score','balls_bowled','wickets_left','crr','city','runs_y']]

# %%
final_df

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df['balls_left'] = 120 - final_df['balls_bowled']
final_df['balls_left'] = final_df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
final_df['crr'] = round((final_df['current_score']*6)/final_df['balls_bowled'],2)

# %%
final_df

# %%
final_df.drop(columns=['balls_bowled'],inplace=True)

# %%
groups = final_df.groupby('match_id')

# %%
match_ids = final_df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30)['runs_x'].sum().values.tolist())

# %%
final_df['last_five'] = last_five

# %%
final_df

# %%
final_df.dropna(inplace=True)

# %%
final_df

# %%
eligible_cities = final_df['city'].value_counts()[final_df['city'].value_counts() > 600].index.tolist()
final_df = final_df[final_df['city'].isin(eligible_cities)]

# %%
X = final_df.drop(columns=['match_id','runs_x','runs_y'])
y = final_df['runs_y']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_test

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
